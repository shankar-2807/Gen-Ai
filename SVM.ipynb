# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('C:/Users/ADMIN/Desktop/FBS/Data Analysis/data set/iris.csv')

# %%
sns.scatterplot(dataset, x="Petal_Length",y="Sepal_Length", hue="Species")
# Out:
# <Axes: xlabel='Petal_Length', ylabel='Sepal_Length'>

# %%
dataset['Species'].value_counts()
# Out:
# Species
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: count, dtype: int64

# %%
dataset1 = pd.read_csv("C:/Users/ADMIN/Desktop/FBS/Data Analysis/data set/iris.csv")

# %%
dataset1.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
dataset1.replace(to_replace="Virginica",value="Non Setosa",inplace=True)

# %%
dataset1.replace(to_replace="Versicolor",value="Non Setosa",inplace=True)

# %%
dataset1['Species'].value_counts()
# Out:
# Species
# Non Setosa    100
# Setosa         50
# Name: count, dtype: int64

# %%
X=dataset1[['Petal_Length','Sepal_Length']].values
y = dataset1['Species'].values

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2,random_state=30)

# %%
from sklearn.svm import SVC

# %%
svm  = SVC()
svm.fit(X_train,y_train)
# Out:
# SVC()

# %%
pip install mlxtend
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train,y_train,svm)
# Out:
# <Axes: >

# %%
X=dataset[['Petal_Length','Sepal_Length']].values
y = dataset['Species'].values

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2,random_state=30)

# %%
svm  = SVC()
svm.fit(X_train,y_train)
# Out:
# SVC()

# %%
plot_decision_regions(X_train,y_train,svm)
# Out:
# <Axes: >

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_train, svm.predict(X_train))
# Out:
# 0.9583333333333334

# %%
X = dataset.iloc[:,:-1].values
y = dataset.iloc[:,-1].values

# %%
X

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2,random_state=30)

# %%
svm  = SVC()
svm.fit(X_train,y_train)
# Out:
# SVC()

# %%
# plot_decision_regions(X_train,y_train,svm)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_train, svm.predict(X_train))
# Out:
# 0.9583333333333334

# %%
accuracy_score(y_test, svm.predict(X_test))
# Out:
# 1.0
