# %%
import numpy as np

# %% [markdown]
# ### Broadcasting
#
# The array which have only one element is broaded equal to another arrat's length of elements

# %%
arr = np.array([10, 20, 30, 40])
arr2 = np.array([10])
arr + arr2
# Out:
# array([20, 30, 40, 50])
