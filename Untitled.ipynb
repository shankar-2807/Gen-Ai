# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('C:/Users/ADMIN/Desktop/FBS/Data Science/Data sets/FMCG.csv')

# %%
dataset
# Out:
#               date     sku     brand        segment  category     channel  \
# 0       2022-01-21  MI-006  MiBrand1      Milk-Seg3      Milk      Retail
# 1       2022-01-21  MI-006  MiBrand1      Milk-Seg3      Milk      Retail
# 2       2022-01-21  MI-006  MiBrand1      Milk-Seg3      Milk      Retail
# 3       2022-01-21  MI-006  MiBrand1      Milk-Seg3      Milk    Discount
# 4       2022-01-21  MI-006  MiBrand1      Milk-Seg3      Milk    Discount
# ...            ...     ...       ...            ...       ...         ...
# 190752  2024-12-31  SN-030  SnBrand2  SnackBar-Seg1  SnackBar    Discount
# 190753  2024-12-31  SN-030  SnBrand2  SnackBar-Seg1  SnackBar    Discount
# 190754  2024-12-31  SN-030  SnBrand2  SnackBar-Seg1  SnackBar  E-commerce
# 190755  2024-12-31  SN-030  SnBrand2  SnackBar-Seg1  SnackBar  E-commerce
# 190756  2024-12-31  SN-030  SnBrand2  SnackBar-Seg1  SnackBar  E-commerce
#
#             region  pack_type  price_unit  promotion_flag  delivery_days  \
# ...

# %%
dataset.isna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190757 entries, 0 to 190756
# Data columns (total 14 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   date             190757 non-null  bool
#  1   sku              190757 non-null  bool
#  2   brand            190757 non-null  bool
#  3   segment          190757 non-null  bool
#  4   category         190757 non-null  bool
#  5   channel          190757 non-null  bool
#  6   region           190757 non-null  bool
#  7   pack_type        190757 non-null  bool
#  8   price_unit       190757 non-null  bool
#  9   promotion_flag   190757 non-null  bool
#  10  delivery_days    190757 non-null  bool
#  11  stock_available  190757 non-null  bool
#  12  delivered_qty    190757 non-null  bool
#  13  units_sold       190757 non-null  bool
# dtypes: bool(14)
# memory usage: 2.5 MB

# %%
plt.boxplot(dataset['price_unit'])
plt.show()

# %%
plt.boxplot(dataset['promotion_flag'])
plt.show()

# %%
plt.boxplot(dataset['delivery_days'])
plt.show()

# %%
plt.boxplot(dataset['stock_available'])
plt.show()

# %%
plt.boxplot(dataset['delivered_qty'])
plt.show()

# %%
plt.boxplot(dataset['units_sold'])
plt.show()
