# %%
pip install spacy
# Out:
# ...
#    ---------------------------------------- 0.0/13.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.9 MB ? eta -:--:--
#     --------------------------------------- 0.3/13.9 MB ? eta -:--:--
#     --------------------------------------- 0.3/13.9 MB ? eta -:--:--
#    - -------------------------------------- 0.5/13.9 MB 541.6 kB/s eta 0:00:25
#    - -------------------------------------- 0.5/13.9 MB 541.6 kB/s eta 0:00:25
#    -- ------------------------------------- 0.8/13.9 MB 645.7 kB/s eta 0:00:21
#    --- ------------------------------------ 1.0/13.9 MB 729.5 kB/s eta 0:00:18
#    --- ------------------------------------ 1.0/13.9 MB 729.5 kB/s eta 0:00:18
#    --- ------------------------------------ 1.3/13.9 MB 737.4 kB/s eta 0:00:18
#    ---- ----------------------------------- 1.6/13.9 MB 822.8 kB/s eta 0:00:16
# ...

# %%
import spacy

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      - -------------------------------------- 0.5/12.8 MB 2.4 MB/s eta 0:00:06
#      -- ------------------------------------- 0.8/12.8 MB 1.8 MB/s eta 0:00:07
#      -- ------------------------------------- 0.8/12.8 MB 1.8 MB/s eta 0:00:07
#      ---- ----------------------------------- 1.6/12.8 MB 1.7 MB/s eta 0:00:07
#      ----- ---------------------------------- 1.8/12.8 MB 1.7 MB/s eta 0:00:07
#      ------ --------------------------------- 2.1/12.8 MB 1.8 MB/s eta 0:00:07
#      -------- ------------------------------- 2.6/12.8 MB 1.8 MB/s eta 0:00:06
#      --------- ------------------------------ 2.9/12.8 MB 1.7 MB/s eta 0:00:06
#      ---------- ----------------------------- 3.4/12.8 MB 1.8 MB/s eta 0:00:06
#      ------------ --------------------------- 3.9/12.8 MB 1.8 MB/s eta 0:00:05
# ...

# %%
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp('We are learning Data Science in FirstBit instuite')
type(doc)
for token in doc:
    print(token.text, token.pos_)
# Out:
# We PRON
# are AUX
# learning VERB
# Data PROPN
# Science PROPN
# in ADP
# FirstBit PROPN
# instuite NOUN

# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
from nltk.stem.porter import*

# %%
p_stemmer = PorterStemmer()

# %%
from nltk.stem import PorterStemmer

words = ['run', 'runner', 'running', 'ran', 'runs', 'easily', 'fearly', 'write', 'beautiful']

# Create stemmer
p_stemmer = PorterStemmer()

# Loop through the list of words
for word in words:
    print(word + ' --> ' + p_stemmer.stem(word))
# Out:
# run --> run
# runner --> runner
# running --> run
# ran --> ran
# runs --> run
# easily --> easili
# fearly --> fearli
# write --> write
# beautiful --> beauti

# %%
doc1 = nlp("I am a runner running in a race because I love to run since I ran today")
for token in doc1:
    print(token.text, '----', token.lemma_)
# Out:
# I ---- I
# am ---- be
# a ---- a
# runner ---- runner
# running ---- run
# in ---- in
# a ---- a
# race ---- race
# because ---- because
# I ---- I
# love ---- love
# to ---- to
# run ---- run
# since ---- since
# I ---- I
# ran ---- run
# today ---- today

# %%
phrase = 'I am meeting him tommorrow at the meeting'
for word in phrase.split():
    print(word + ' --> '+ p_stemmer.stem(word))
# Out:
# I --> i
# am --> am
# meeting --> meet
# him --> him
# tommorrow --> tommorrow
# at --> at
# the --> the
# meeting --> meet

# %% [markdown]
# ### Lemmatization

# %%
words = nlp('run runner running ran runs easily fairly written beautiful')
for token in words:
    print(token.text, '----', token.lemma_)
# Out:
# run ---- run
# runner ---- runner
# running ---- running
# ran ---- run
# runs ---- run
# easily ---- easily
# fairly ---- fairly
# written ---- write
# beautiful ---- beautiful

# %%
sent = nlp(' I am a runner in running race')
for token in sent:
    print(token.text, '----', token.lemma_)
# Out:
#   ----
# I ---- I
# am ---- be
# a ---- a
# runner ---- runner
# in ---- in
# running ---- run
# race ---- race
